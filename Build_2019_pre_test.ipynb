# %%
import pandas as pd
import numpy as np

import requests 
from pprint import pprint

# %%
query_all_2018_movies ='https://api.themoviedb.org/3/discover/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&language=en-US&sort_by=vote_average.desc&include_adult=false&include_video=false&page=1&primary_release_year=2018'

# %%
response=requests.get(query_all_2018_movies).json()

# %%
response
# Out:
# {'page': 1,
#  'total_results': 12388,
#  'total_pages': 620,
#  'results': [{'vote_count': 15,
#    'id': 459243,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Screwed',
#    'popularity': 18.225,
#    'poster_path': '/3kQXgfTYSAC9RvlxWStKohWSXeG.jpg',
#    'original_language': 'fi',
#    'original_title': 'Pihalla',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/uIdrHXDrQboiLYnMWzad3TOYxyV.jpg',
#    'adult': False,
#    'overview': 'Seventeen-year-olds Miku and Elias find themselves, and each other, during a summer in the Finnish countryside.',
#    'release_date': '2018-11-30'},
#   {'vote_count': 4,
#    'id': 556173,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Requiem for a Fighter',
#    'popularity': 2.508,
#    'poster_path': '/7GR9aqiFp1e6YVEvHz1W8BQWhBG.jpg',
#    'original_language': 'en',
#    'original_title': 'Requiem for a Fighter',
#    'genre_ids': [],
#    'backdrop_path': '/jBCnv5yicOasoVQ8ysrBv7Z3ar3.jpg',
#    'adult': False,
#    'overview': "Lucas A former Danish Army Officer has traveled to Derry, Northern Ireland to clear up details of his estranged son's death and finds that there was another side to his son's life and the people he was partied with. These include Michael who has been fighting in unlicensed boxing matches to raise quick cash, trained by his Father who doesn't know Michael is questioning his sexuality. The fights have been building to a final fight against Brian Beru, undefeated King of the gypsy's and a wrecking machine, Michael will need Lucas help if he is to survive.",
#    'release_date': '2018-11-12'},
#   {'vote_count': 3,
#    'id': 550286,
#    'video': False,
#    'vote_average': 10,
#    'title': "Don't Open Your Eyes",
#    'popularity': 4.525,
#    'poster_path': '/fIYTqODecTdoKcY0Gk9g0T0XEpw.jpg',
#    'original_language': 'en',
#    'original_title': "Don't Open Your Eyes",
#    'genre_ids': [18, 27],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A home-care nurse takes a job, but as it proves to be his toughest yet; he is inadvertently pulled into something much more sinister.',
#    'release_date': '2018-10-31'},
#   {'vote_count': 3,
#    'id': 491628,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Chanda Mama Door Ke',
#    'popularity': 1.637,
#    'poster_path': None,
#    'original_language': 'hi',
#    'original_title': 'Chanda Mama Door Ke',
#    'genre_ids': [878, 18],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A biopic about the Indian space programme.',
#    'release_date': '2018-01-26'},
#   {'vote_count': 2,
#    'id': 549550,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Brutal',
#    'popularity': 0.6,
#    'poster_path': '/uAl6Q47rrPYJvqVzFnKVbAZoOap.jpg',
#    'original_language': 'fr',
#    'original_title': 'Brutal',
#    'genre_ids': [27, 28, 14],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': '',
#    'release_date': '2018-04-21'},
#   {'vote_count': 2,
#    'id': 548876,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Mother and I',
#    'popularity': 0.6,
#    'poster_path': '/zjGC2twdjQl2UM5rM7N4b5GXEfu.jpg',
#    'original_language': 'en',
#    'original_title': 'Mother and I',
#    'genre_ids': [53],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A young man uncovers the dark reality of a traumatic event.',
#    'release_date': '2018-05-05'},
#   {'vote_count': 2,
#    'id': 548682,
#    'video': False,
#    'vote_average': 10,
#    'title': 'No One Would Tell',
#    'popularity': 2.564,
#    'poster_path': '/cqx875MTqawWQFDLWrKR1KkSZ9e.jpg',
#    'original_language': 'en',
#    'original_title': 'No One Would Tell',
#    'genre_ids': [18, 53, 9648, 10770],
#    'backdrop_path': '/lupaY5QeER9J954azDn9YYV3pyU.jpg',
#    'adult': False,
#    'overview': 'Laura Collins (Shannen Doherty), single mom to daughter Sarah (Matreya Scarrwener), has had a history of rocky relationships, so when Sarah begins dating the popular and charismatic Rob Tennison (Callan Potter), Laura is thrilled with what she sees. But when it becomes increasingly clear that Rob has a darker, possessive side, Laura lives in a state of denial about her daughter’s relationship until Sarah goes missing. Laura must find the will to fight for justice for Sarah when a case against Rob is brought to trial and presided over by a powerful judge (Mira Sorvino).',
#    'release_date': '2018-09-16'},
#   {'vote_count': 2,
#    'id': 541076,
#    'video': False,
#    'vote_average': 10,
#    'title': 'The Revenge of Lemonade Bill',
#    'popularity': 0.6,
#    'poster_path': '/t1TKPNL72QHUIcYWSuQdRBhgb13.jpg',
#    'original_language': 'pt',
#    'original_title': 'A Vingança de Bill Limonada',
#    'genre_ids': [35, 37],
#    'backdrop_path': '/wl76pYwHXwMOVK3wkaBVYFIlNPP.jpg',
#    'adult': False,
#    'overview': "Limeville, the city of lime, fears it's legacy might be destroyed when the heirs of the land show up to claim the town and replace the lime with oranges. But there's only place for one fruit in this town...",
#    'release_date': '2018-08-11'},
#   {'vote_count': 2,
#    'id': 538112,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Happy Phirr Bhag Jayegi',
#    'popularity': 5.513,
#    'poster_path': '/6ZGPJgK9qMlQopwfRBeL8t1yltX.jpg',
#    'original_language': 'hi',
#    'original_title': 'हैप्पी फिर भाग जाएगी',
#    'genre_ids': [18, 10749, 35],
#    'backdrop_path': '/no67zxKlOpV7zQdT2Atf7ljn4WA.jpg',
#    'adult': False,
#    'overview': 'Horticulture professor Happy arrives in Shanghai and the other Happy along with husband Guddu also lands up in the Chinese city at the same time. Gangsters who’ve come to kidnap Happy and her husband, pick up the wrong Happy, while Guddu and his wife Happy are escorted to a university to deliver a lecture.',
#    'release_date': '2018-08-24'},
#   {'vote_count': 2,
#    'id': 536720,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Winter Will Not Be',
#    'popularity': 1.001,
#    'poster_path': '/ryGCkTvluSNynS8Nu5N3yakHCZj.jpg',
#    'original_language': 'ru',
#    'original_title': 'Зимы не будет',
#    'genre_ids': [10402],
#    'backdrop_path': '/dYwvl6n4U6DERioNVsOgLg3JNRB.jpg',
#    'adult': False,
#    'overview': '"There will be no winters" - a film consisting of 14 short novels, each with its own plot and a musical theme. In fact, this is a screen version of the same album of Russian avant-garde singer Leonid Fedorov.',
#    'release_date': '2018-06-08'},
#   {'vote_count': 2,
#    'id': 536650,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Solo',
#    'popularity': 0.6,
#    'poster_path': '/uucyc7PsmvSd5Ser3Uhn22aUnBY.jpg',
#    'original_language': 'pt',
#    'original_title': 'Solo',
#    'genre_ids': [9648],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': '"Solo" tells the story of J, a saxophonist who finds a heart beating in his saxophone case, on the eve of his big concert at the International Jazz Show.',
#    'release_date': '2018-06-23'},
#   {'vote_count': 2,
#    'id': 536163,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Ace Walker',
#    'popularity': 0.6,
#    'poster_path': '/icTbKr3yIYabbQIGI5r2j22omRF.jpg',
#    'original_language': 'en',
#    'original_title': 'Ace Walker',
#    'genre_ids': [28],
#    'backdrop_path': '/mHzPoEqhsOMoWuAecq85y8fkBLL.jpg',
#    'adult': False,
#    'overview': 'CIA agent Ace Walker (Eddie Daou) is on his latest mission - retrieve a drive containing the names of every CIA agent ever.',
#    'release_date': '2018-03-18'},
#   {'vote_count': 2,
#    'id': 534719,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Bossferatu',
#    'popularity': 0.6,
#    'poster_path': '/6mHVcXB44OOku0y82EHUNNJSRW5.jpg',
#    'original_language': 'de',
#    'original_title': 'Bossferatu',
#    'genre_ids': [35, 99, 18],
#    'backdrop_path': '/bOPs76Jji2KrwTq2xXlDy5AxTm9.jpg',
#    'adult': False,
#    'overview': "The true story of Germany's biggest Boy Band.  Follow Adam and Tjark on their miraculous quest to bring the band back together.  Includes exclusive Interviews and brand new behind-the-scenes material.",
#    'release_date': '2018-07-13'},
#   {'vote_count': 2,
#    'id': 528505,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Sieben Stunden',
#    'popularity': 1.4,
#    'poster_path': '/1dC0HThZHTImBIR1R8M0uTLYiJf.jpg',
#    'original_language': 'de',
#    'original_title': 'Sieben Stunden',
#    'genre_ids': [18],
#    'backdrop_path': '/2u51BEUyCahppCGkdnEVJJNTDwJ.jpg',
#    'adult': False,
#    'overview': 'She has her life firmly under control - but then the unbelievable happens. For seven hours, Hanna, who works as a psychotherapist in a Bavarian high-security prison, is taken hostage in her office by one of her patients. She is at the mercy of her tormentor, whom she has recently made a positive prognosis, and is raped several times. While the SEK Hanna, who is standing in front of the door, looks to safety, a convicted rapist destroys the life of a wife, mother and self-confident, cheerful woman. After the fact, nothing is as it was.',
#    'release_date': '2018-10-01'},
#   {'vote_count': 2,
#    'id': 520576,
#    'video': False,
#    'vote_average': 10,
#    'title': 'After the Rain',
#    'popularity': 4.175,
#    'poster_path': '/fAx1Q5RsZ57w6evOLPf4iMEEMLR.jpg',
#    'original_language': 'ja',
#    'original_title': '恋は雨上がりのように',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/mNVqvvxUSG5IK8MCrWMGkRvHVgK.jpg',
#    'adult': False,
#    'overview': 'Akira Tachibana is a 17-year-old high school student. She was once a promising athlete, but an injury has prevented her from taking part in track and field. One day, Akira Tachibana goes to a family restaurant and the manager talks to her in a tender voice. This makes Akira Tachibana begin working part-time at the restaurant. The manager is 45-year-old Masami Kondo and he is divorced with a child. Akira Tachibana falls in love with him. --asianwiki',
#    'release_date': '2018-05-25'},
#   {'vote_count': 2,
#    'id': 519242,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Bro Night',
#    'popularity': 0.6,
#    'poster_path': '/882VjrLrckQ1E8qfIimWFPDVJFV.jpg',
#    'original_language': 'en',
#    'original_title': 'Bro Night',
#    'genre_ids': [35, 9648, 28],
#    'backdrop_path': '/vkdJPLYgjr2xJ5BsMuAfsIBVRL1.jpg',
#    'adult': False,
#    'overview': 'Bro Night follows the story of three bros who during their weekly Bro Night get a mysterious phone call that will change their lives forever.',
#    'release_date': '2018-04-20'},
#   {'vote_count': 2,
#    'id': 515850,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Nyctophobia',
#    'popularity': 0.974,
#    'poster_path': '/6mWLekrRJFdXD4sBmdI0tSPpxLr.jpg',
#    'original_language': 'en',
#    'original_title': 'Nyctophobie',
#    'genre_ids': [],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Jean-François Boisvenue tells us about his childhood fears and his history of mental illness. On the screen, we can see a series of hand-drawn animations projected onto his body that plunges us into psychosis and depersonalization. The whole was captured by the camera without postproduction effects.',
#    'release_date': '2018-02-01'},
#   {'vote_count': 2,
#    'id': 515264,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Hall American: Forbidden',
#    'popularity': 0.717,
#    'poster_path': '/1K1477QWuZ86q8urc9IjJr4T7vo.jpg',
#    'original_language': 'en',
#    'original_title': 'Hall American: Forbidden',
#    'genre_ids': [18, 10402],
#    'backdrop_path': '/7LD18Y2V7FtPSryQoio6jOKPPEy.jpg',
#    'adult': False,
#    'overview': '',
#    'release_date': '2018-03-15'},
#   {'vote_count': 2,
#    'id': 514505,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Moving Parts',
#    'popularity': 0.6,
#    'poster_path': '/jiGSiFUhyFJderGl2NhvaQQvU5n.jpg',
#    'original_language': 'en',
#    'original_title': 'Moving Parts',
#    'genre_ids': [28, 18],
#    'backdrop_path': '/xW5g2vAUZFEWbsUyma54EbsCXHY.jpg',
#    'adult': False,
#    'overview': "Two very opposite couples are drawn into organized crime and it doesn't take long until you realize everything and everyone is not what they seem..",
#    'release_date': '2018-03-27'},
#   {'vote_count': 2,
#    'id': 512898,
#    'video': False,
#    'vote_average': 10,
#    'title': 'Dhh',
#    'popularity': 2.985,
#    'poster_path': '/7tJ5kxdBO0LxRaEkmLaWKZydFZB.jpg',
#    'original_language': 'gu',
#    'original_title': 'Dhh',
#    'genre_ids': [18, 10751],
#    'backdrop_path': '/tR2riRDgLSfn5hNu2TCtO8TOCmg.jpg',
#    'adult': False,
#    'overview': 'Dhh is a heartwarming story of 3 friends (Gungun, Bajrang and Vakil) and their journey towards realising their true potential. An afternoon of sauntering leads them to a magic show and leaves them awestruck. Magic, it seems is a solution for all their problems including mathematics. The boys write to the Magician asking him for a trick to ace their examinations. Days go by and times get tougher with punishments at school and warnings at home. All hope is lost, but one fine day the Magician replies. His letter arrives with a parcel that claims to hold the key to cracking their examinations. Can this be true? In pursuit of learning from magic Gungun and his friends soon realise, that there is a lot more learning to be done from life itself.',
#    'release_date': '2018-09-28'}]}

# %%
# use api.tmdb.org due to problem of 'query limit is 40'
base_url ='https://api.tmdb.org/3/search/movie?'
api_key = 'api_key=d5b4e5d5145be601d4640d76efd791e3'
query = '&query='
query_base_url = base_url + api_key + query

# best_pic_info: get the movie summary information 
best_pic_2019 = []

for i in range(len(Cont_2019_db_name)): 
    release_year = '2018'
    movie_info = query_base_url + Cont_2019_db_name[i] + '&year=' + release_year
    print(movie_info)
    response=requests.get(movie_info).json()
    best_pic_2019.append(response['results'])
# Out:
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Call Me by Your Name&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Darkest Hour&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Dunkirk&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Get Out&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Lady Bird&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Phantom Thread&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=The Post&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=The Shape of Water&year=2018
# https://api.tmdb.org/3/search/movie?api_key=d5b4e5d5145be601d4640d76efd791e3&query=Three Billboards Outside Ebbing, Missouri&year=2018

# %%
base_url1 = 'https://api.tmdb.org/3/movie/'

#language = '&language=en-US'
keyword = '/keywords?'
Winner2019_Details= []
keyword_details = []
tmdb_id_list = []
#keywords: https://api.themoviedb.org/3/movie/23383/keywords?api_key=d5b4e5d5145be601d4640d76efd791e3

for i in range(len(best_pic_2019)):
    tmdb_id = str(best_pic_2019[i][0]['id'])
    tmdb_id_list.append(best_pic_2019[i][0]['id'])
    detail_query_link = base_url1 + tmdb_id + '?' + api_key #+ language
    keywords_query_link = base_url1 + tmdb_id + keyword + api_key
    response = requests.get(detail_query_link).json()
    keywords_response = requests.get(keywords_query_link).json()
    Winner2019_Details.append(response)
    keyword_details.append(keywords_response)

# %%
winning_keywords = []
keywords_list = []

for i in range(len(keyword_details)):
    for j in range(len(keyword_details[i]['keywords'])):
        winning_keywords.append(keyword_details[i]['keywords'][j]['name'])
    keywords_list.append(keyword_details[i]['keywords'])

# %%
revenue_list = []
budget_list = []
runtime_list = []
vote_average_list = []
vote_count_list =[]
pop_list = []
genre_list =[]
release_date_list = []


for i in range(len(Winner2019_Details)):
    revenue_list.append(Winner2019_Details[i]['revenue'])
    budget_list.append(Winner2019_Details[i]['budget'])
    runtime_list.append(Winner2019_Details[i]['runtime'])
    vote_average_list.append(Winner2019_Details[i]['vote_average'])
    vote_count_list.append(Winner2019_Details[i]['vote_count'])
    pop_list.append(Winner2019_Details[i]['popularity'])
    genre_list.append(Winner2019_Details[i]['genres'])
    release_date_list.append(Winner2019_Details[i]['release_date'])


release_month_list = []
for i in range(len(release_date_list)):
    release_month = release_date_list[i].split('-')
    release_month_list.append(release_month[1])
    

Cont_2019_db['id'] = pd.Series(tmdb_id_list).values
Cont_2019_db['revenue'] = pd.Series(revenue_list).values
Cont_2019_db['budget'] =  pd.Series(budget_list).values
Cont_2019_db['runtime'] = pd.Series(runtime_list).values
Cont_2019_db['vote_average'] = pd.Series(vote_average_list).values
Cont_2019_db['vote_count'] = pd.Series(vote_count_list).values
Cont_2019_db['popularity'] = pd.Series(pop_list).values
Cont_2019_db['genres'] = pd.Series(genre_list).values
Cont_2019_db['release_month'] = pd.Series(release_month_list).values
Cont_2019_db['keywords'] = pd.Series(keywords_list).values

# %%
def get_names(keywords):
    return '|'.join([x['name'] for x in keywords]) 



Cont_2019_db['keywords'] = Cont_2019_db['keywords'].apply(get_names)
Cont_2019_db['genres'] = Cont_2019_db['genres'].apply(get_names)

Cont_2019_db.head()
# Out:
#    Year         Award    won                  name      id    revenue  \
# 0  2017  BEST PICTURE  False  Call Me by Your Name  398818   41063475
# 1  2017  BEST PICTURE  False          Darkest Hour  399404  147568410
# 2  2017  BEST PICTURE  False               Dunkirk  374720  525573161
# 3  2017  BEST PICTURE  False               Get Out  497223          0
# 4  2017  BEST PICTURE  False             Lady Bird  391713   76858273
#
#       budget  runtime  vote_average  vote_count  popularity  \
# 0    4000000      132           8.3        3722      16.849
# 1   30000000      125           7.3        2162      13.953
# 2  100000000      107           7.4        7686      21.633
# 3          0      105           6.5           5       3.564
# 4   10000000       94           7.3        2958      17.112
#
#                               genres release_month  \
# 0                      Romance|Drama            09
# 1                      Drama|History            11
# 2  Action|Drama|History|Thriller|War            07
# 3              Action|Drama|Thriller            04
# 4                       Comedy|Drama            09
#
#                                             keywords
# 0  italy|upper class|based on novel or book|swimm...
# 1  world war ii|biography|london underground|base...
# 2  france|beach|europe|world war ii|evacuation|ge...
# 3                               car bomb|blackmailer
# 4  coming of age|best friend|loss of job|catholic...

# %%
genre_weight_dict ={'Drama': 0.36587982832618027,\
                    'Romance': 0.12339055793991416,\
                    'Comedy': 0.0815450643776824,\
                    'History': 0.06759656652360516,\
                    'Thriller': 0.0611587982832618,\
                    'Crime': 0.05042918454935622,\
                    'Adventure': 0.046137339055793994,\
                    'War': 0.043991416309012876,\
                    'Action': 0.03755364806866953,\
                    'Mystery': 0.02467811158798283,\
                    'Fantasy': 0.022532188841201718,\
                    'Music': 0.022532188841201718,\
                    'Family': 0.0203862660944206,\
                    'Western': 0.015021459227467811,\
                    'Science Fiction': 0.01072961373390558,\
                    'Animation': 0.003218884120171674,\
                    'Horror': 0.003218884120171674,\
                    'other': 0.05882352941176469}

# %%
genre_list = list(Cont_2019_db['genres'])
w_genre_list = genre_weight_dict.keys()

weight=0
weight_list = []

for i in range(len(genre_list)):
    onefilm = genre_list[i].split('|')
    for j in range(len(onefilm)):
        if onefilm[j] in w_genre_list:
            weight  += genre_weight_dict[onefilm[j]]
        else:
             weight  += genre_weight_dict['other']
        
    weight_list.append(weight)
    weight = 0

# %%
Cont_2019_db['genre_weight'] = weight_list

# %%
Cont_2019_db.release_month = Cont_2019_db.release_month.astype(int)

# %%
Cont_2019_db['profit'] = Cont_2019_db['revenue'] - Cont_2019_db['budget']

# %%
Cont_2019_db
# Out:
#    Year         Award    won                                       name  \
# 0  2017  BEST PICTURE  False                       Call Me by Your Name
# 1  2017  BEST PICTURE  False                               Darkest Hour
# 2  2017  BEST PICTURE  False                                    Dunkirk
# 3  2017  BEST PICTURE  False                                    Get Out
# 4  2017  BEST PICTURE  False                                  Lady Bird
# 5  2017  BEST PICTURE  False                             Phantom Thread
# 6  2017  BEST PICTURE  False                                   The Post
# 7  2017  BEST PICTURE   True                         The Shape of Water
# 8  2017  BEST PICTURE  False  Three Billboards Outside Ebbing, Missouri
#
#        id    revenue     budget  runtime  vote_average  vote_count  \
# 0  398818   41063475    4000000      132           8.3        3722
# 1  399404  147568410   30000000      125           7.3        2162
# 2  374720  525573161  100000000      107           7.4        7686
# 3  497223          0          0      105           6.5           5
# 4  391713   76858273   10000000       94           7.3        2958
# 5  400617   46261438   35000000      131           7.2        1215
# 6  446354  174503458   50000000      116           7.0        1973
# 7  399055  194989655   19500000      123           7.3        5686
# 8  359940  158526998   15000000      115           8.2        4219
#
#    popularity                             genres  release_month  \
# 0      16.849                      Romance|Drama              9
# 1      13.953                      Drama|History             11
# 2      21.633  Action|Drama|History|Thriller|War              7
# 3       3.564              Action|Drama|Thriller              4
# 4      17.112                       Comedy|Drama              9
# 5      10.017                      Drama|Romance             12
# 6      11.181                      Drama|History             12
# 7      21.903              Drama|Fantasy|Romance             12
# 8      15.942                        Crime|Drama             11
#
#                                             keywords  genre_weight     profit
# 0  italy|upper class|based on novel or book|swimm...      0.489270   37063475
# 1  world war ii|biography|london underground|base...      0.433476  117568410
# 2  france|beach|europe|world war ii|evacuation|ge...      0.576180  425573161
# 3                               car bomb|blackmailer      0.464592          0
# 4  coming of age|best friend|loss of job|catholic...      0.447425   66858273
# 5  london england|wife husband relationship|obses...      0.489270   11261438
# 6  journalism|newspaper|biography|politics|govern...      0.433476  124503458
# 7  cold war|baltimore|fairy tale|government|super...      0.511803  175489655
# 8  suicide|rape|small town|missouri|alcoholism|mu...      0.416309  143526998

# %%
features = ['id','budget','popularity','release_month','revenue','runtime','vote_average','vote_count','genre_weight','profit']

# %%
test_set_2019 = Cont_2019_db[features]

# %%
#test_set_2019.to_csv('./DataSources/test2019_tmdb.csv')

# %%
test_set_2019.to_csv('./DataSources/test2017_tmdb.csv')
